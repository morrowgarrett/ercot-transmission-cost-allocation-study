# %% [markdown]
# # Comparative Evaluation Notebook
#
# This notebook is public-safe and uses synthetic example inputs only.
# It demonstrates how to run the shared methodology suite and inspect the comparison bundle.

# %%
from src.comparison.scorecard import build_comparison_bundle
from src.models.base import MethodologyInputs

# %% [markdown]
# Populate `MethodologyInputs` with synthetic or public-safe example data, then call `build_comparison_bundle(inputs)`.
#
# The test suite contains working synthetic fixtures in `tests/test_comparison.py` and `tests/test_cbtca.py`.
