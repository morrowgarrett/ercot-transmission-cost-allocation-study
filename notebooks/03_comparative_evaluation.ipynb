# %% [markdown]
# # Comparative Evaluation Notebook
#
# This notebook is public-safe and uses synthetic example inputs only.
# It demonstrates how to run the shared methodology suite and inspect the comparison bundle.

# %%
from src.comparison.scorecard import build_comparison_bundle
from src.comparison.synthetic_data import build_four_zone_synthetic_inputs, synthetic_dataset_metadata

# %% [markdown]
# This notebook should use `build_four_zone_synthetic_inputs()` from `src/comparison/synthetic_data.py` for public-safe examples.
#
# See `docs/synthetic-data.md` for the exact synthetic-vs-real boundary and the intended edge cases (high-BTM WEST, export-heavy net-load behavior, four-zone coverage).
